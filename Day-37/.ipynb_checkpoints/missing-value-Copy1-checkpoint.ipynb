# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])

# %%
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
df['GarageQual'].mode()
# Out:
# 0    TA
# Name: GarageQual, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax)

df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines, labels = ax.get_legend_handels_labels()
labels= ['Houses with TA','Houses with NA']
ax.legend(lines,labels , loc='best')

plt.title('GarageQual')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 9
#       5 df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax)
#       7 df[df['GarageQual'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')
# ----> 9 lines, labels = ax.get_legend_handels_labels()
#      10 labels= ['Houses with TA','Houses with NA']
#      11 ax.legend(lines,labels , loc='best')
#
# AttributeError: 'Axes' object has no attribute 'get_legend_handels_labels'

# %%
temp =df[df['GarageQual'] =='TA']['SalePrice']

# %%
df['GarageQual'].fillna('TA' , inplace=True)

# %%
df['GarageQual'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='GarageQual'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde',ax=ax)

df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines, labels = ax.get_legend_handels_labels()
labels= ['Original','After Impute']
ax.legend(lines,labels , loc='best')

plt.title('GarageQual')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 9
#       5 temp.plot(kind='kde',ax=ax)
#       7 df[df['GarageQual']=='TA']['SalePrice'].plot(kind='kde',ax=ax,color='red')
# ----> 9 lines, labels = ax.get_legend_handels_labels()
#      10 labels= ['Original','After Impute']
#      11 ax.legend(lines,labels , loc='best')
#
# AttributeError: 'Axes' object has no attribute 'get_legend_handels_labels'

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax)

df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines, labels = ax.get_legend_handels_labels()
labels= ['Houses with GD','Houses with NA']
ax.legend(lines,labels , loc='best')

plt.title('FireplaceQu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 9
#       5 df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax)
#       7 df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde',ax=ax,color='red')
# ----> 9 lines, labels = ax.get_legend_handels_labels()
#      10 labels= ['Houses with GD','Houses with NA']
#      11 ax.legend(lines,labels , loc='best')
#
# AttributeError: 'Axes' object has no attribute 'get_legend_handels_labels'

# %%
temp =df[df['FireplaceQu'] =='Gd']['SalePrice']

# %%
df['FireplaceQu'].fillna('Gd' , inplace=True)

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde',ax=ax)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax,color='red')

lines, labels = ax.get_legend_handels_labels()
labels= ['Original','After Imputation']
ax.legend(lines,labels , loc='best')

plt.title('FireplaceQu')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 9
#       5 temp.plot(kind='kde',ax=ax)
#       7 df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde',ax=ax,color='red')
# ----> 9 lines, labels = ax.get_legend_handels_labels()
#      10 labels= ['Original','After Imputation']
#      11 ax.legend(lines,labels , loc='best')
#
# AttributeError: 'Axes' object has no attribute 'get_legend_handels_labels'

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)
# Out:
# C:\Users\Lenova\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(

# %%
imputer.statistics_
# Out:
# array(['Gd', 'TA'], dtype=object)
